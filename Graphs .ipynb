# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
tree=['Boosted','Bagged','RUSBoosted','Optimizble Ensemble']
precision = (93.38, 91.11, 91.1, 91.85)
recall = (88.81, 87.86, 89.13, 88.57)
f1 = (91.04, 89.45, 90.11, 90.18)
accuracy = (90.4, 88.8, 89.6, 90.8)
xpos=np.arange(len(precision))
plt.style.use('default')
plt.figure(figsize=(7,6))
barwidth=0.2
plt.bar(xpos,precision,color='cornflowerblue',width=barwidth,label='precision')
plt.bar(xpos+0.2,recall,color='salmon',width=barwidth,label='recall')
plt.bar(xpos+0.4,f1,color='lightgreen',width=barwidth,label='f1')
plt.bar(xpos+0.6,accuracy,color='plum',width=barwidth,label='accuracy')
plt.xticks(xpos + 0.2, tree)
plt.xlabel('ML techniques')
plt.ylabel('Percentage(%)')
plt.title('Performance Metrics for Ensemble classifier Model at 12 Features')
plt.ylim(80, 95)
plt.legend(frameon=False, loc='upper center', ncol=4, bbox_to_anchor=(0.5, -0.15), bbox_transform=plt.gca().transAxes)

# %%
features=[12,10,8,6,4]
precision = (93.38,92.59,91.13,94.07,91.85)
recall = (88.81,89.29,89.82,85.81,89.75)
f1 = (91.04,90.91,90.47,89.75,88.57)
accuracy = (90.4,90.4,90,88.8,87.7)
xpos=np.arange(len(precision))
plt.style.use('default')
plt.figure(figsize=(7,6))
barwidth=0.2
plt.bar(xpos,precision,color='cornflowerblue',width=barwidth,label='precision')
plt.bar(xpos+0.2,recall,color='salmon',width=barwidth,label='recall')
plt.bar(xpos+0.4,f1,color='lightgreen',width=barwidth,label='f1')
plt.bar(xpos+0.6,accuracy,color='plum',width=barwidth,label='accuracy')
plt.xticks(xpos + 0.2, features)
plt.xlabel('number of features')
plt.ylabel('Percentage(%)')
plt.title('Performance Metrics for Boosted trees with MRMR')
plt.ylim(80, 95)
plt.legend(frameon=False, loc='upper center', ncol=4, bbox_to_anchor=(0.5, -0.15), bbox_transform=plt.gca().transAxes)

# %%
features=[12,10,8,6,4]
precision = (91.11, 91.95, 92.59, 88.24, 88.57)
recall = (87.86, 86.74, 85.62, 88.24, 86.61)
f1 = (89.45, 89.21, 88.97, 88.24, 87.58)
accuracy = (88.8, 88.4, 88.1, 87.7, 87.0)
xpos=np.arange(len(precision))
plt.style.use('default')
plt.figure(figsize=(7,6))
barwidth=0.2
plt.bar(xpos,precision,color='cornflowerblue',width=barwidth,label='precision')
plt.bar(xpos+0.2,recall,color='salmon',width=barwidth,label='recall')
plt.bar(xpos+0.4,f1,color='lightgreen',width=barwidth,label='f1')
plt.bar(xpos+0.6,accuracy,color='plum',width=barwidth,label='accuracy')
plt.xticks(xpos + 0.2, features)
plt.xlabel('number of features')
plt.ylabel('Percentage(%)')
plt.title('Performance of Bagged tree with MRMR at Various Features')
plt.ylim(80, 95)
plt.legend(frameon=False, loc='upper center', ncol=4, bbox_to_anchor=(0.5, -0.15), bbox_transform=plt.gca().transAxes)

# %%
features=[12,10,8,6,4]
precision = (91.1, 94.81, 92.65, 93.33, 90.37)
recall = (89.13, 85.46, 83.44, 85.14, 85.92)
f1 = (90.11, 90.69, 87.8, 89.05, 88.09)
accuracy = (89.6, 89.5, 89.1, 88.1, 87.3)
xpos=np.arange(len(precision))
plt.style.use('default')
plt.figure(figsize=(7,6))
barwidth=0.2
plt.bar(xpos,precision,color='cornflowerblue',width=barwidth,label='precision')
plt.bar(xpos+0.2,recall,color='salmon',width=barwidth,label='recall')
plt.bar(xpos+0.4,f1,color='lightgreen',width=barwidth,label='f1')
plt.bar(xpos+0.6,accuracy,color='plum',width=barwidth,label='accuracy')
plt.xticks(xpos + 0.2, features)
plt.xlabel('number of features')
plt.ylabel('Percentage(%)')
plt.title('Performance Metrics for RUSBoosted trees with MRMR')
plt.ylim(80, 95)
plt.legend(frameon=False, loc='upper center', ncol=4, bbox_to_anchor=(0.5, -0.15), bbox_transform=plt.gca().transAxes)

# %%
features=[12,10,8,6,4]
precision = (91.85, 92.59, 91.85, 91.91, 93.33)
recall = (88.57, 88.03, 91.85, 88.03, 86.3)
f1 = (90.18, 90.25, 91.85, 89.93, 89.68)
accuracy = (90.8, 90.2, 90.0, 89.2, 88.8)
xpos=np.arange(len(precision))
plt.style.use('default')
plt.figure(figsize=(7,6))
barwidth=0.2
plt.bar(xpos,precision,color='cornflowerblue',width=barwidth,label='precision')
plt.bar(xpos+0.2,recall,color='salmon',width=barwidth,label='recall')
plt.bar(xpos+0.4,f1,color='lightgreen',width=barwidth,label='f1')
plt.bar(xpos+0.6,accuracy,color='plum',width=barwidth,label='accuracy')
plt.xticks(xpos + 0.2, features)
plt.xlabel('number of features')
plt.ylabel('Percentage(%)')
plt.title('Performance Metrics for Optimizble ensemble with MRMR')
plt.ylim(80, 95)
plt.legend(frameon=False, loc='upper center', ncol=4, bbox_to_anchor=(0.5, -0.15), bbox_transform=plt.gca().transAxes)

# %%
features = ['Aspect_Ratio','Equiv_Diameter','Solidity','Extent','Major_Axis_Length','Minor_Axis_Length','Roundness','Compactness','Perimeter','Eccentricity','Convex_Area','Area']
values = [0.3654,0.2986,0.2986,0.2799,0.1899,0.1778,0.1357,0.0858,0.0666,0.0623,0.0107,0.0082]
plt.figure(figsize=(6,6))
plt.bar(features, values, color='plum', width=0.4) 
plt.xticks(rotation=45, ha='right')
plt.title('Features impotance scores sorted Using Minimum Redundancy Maximum Relevance (MRMR) Method')
plt.xlabel('Features')
plt.ylabel('Values')
plt.show()
